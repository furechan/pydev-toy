# %%
from packaging.version import Version

versions = ["0.0.8", "0.0.9", "0.0.10", "0.0.11"]

sorted(versions)
# Out:
# ['0.0.10', '0.0.11', '0.0.8', '0.0.9']

# %%
[Version(v) for v in versions]
# Out:
# [<Version('0.0.8')>,
#  <Version('0.0.9')>,
#  <Version('0.0.10')>,
#  <Version('0.0.11')>]

# %%
sorted(versions, key=Version)
# Out:
# ['0.0.8', '0.0.9', '0.0.10', '0.0.11']

# %%
v = Version("0.1.10")
v
# Out:
# <Version('0.1.10')>

# %%
v
# Out:
# <Version('0.1.10')>

# %%
v = Version("0.1.2.dev0")
v
# Out:
# <Version('0.1.2.dev0')>

# %%
v == v.base_version
# Out:
# False

# %%
v = Version("0.1.2")
v == v.base_version
# Out:
# False

# %%
v.base_version
# Out:
# '0.1.2'

# %%
v
# Out:
# <Version('0.1.2')>

# %%
import re

# %%
re.search(r"a|b|c|rc|dev", "0.1.2.dev0")
# Out:
# <re.Match object; span=(6, 9), match='dev'>

# %%
'dev' in "1.2.3.dev0"
# Out:
# True
